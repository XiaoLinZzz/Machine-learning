# %% [markdown]
# # Assignment 2: Classification
# # Using Machine Learning Tools CS3317
#
# ## Overview
#
# In this assignment, you will apply some popular machine learning techniques to the problem of classifying data from histological cell images for the diagnosis of malignant breast cancer. This will be presented as a practical scenario where you are approached by a client to solve a problem.
#
# The main aims of this assignment are:
#
# - to use the best practice machine learning workflow for producing a solution to a client's problem;
# - to visualise data and determine the best pre-processing;
# - to create the necessary datasets for training and testing purposes;
# - to train and optimise a selection of models, then choose the best;
# - to obtain an unbiased measurement of the final model's performance;
# - to interpret results clearly and concisely.
#
# This assignment relates to the following ACS CBOK areas: abstraction, design, hardware and software, data and information, HCI and programming.
#
# ## General instructions
#
# This assignment is divided into several tasks. Use the spaces provided in this notebook to answer the questions posed in each task. Note that some questions require writing a small amount of code, some require graphical results, and some require comments or analysis as text. It is your responsibility to make sure your responses are clearly labelled and your code has been fully executed (**with the correct results displayed**) before submission!
#
# **Do not** manually edit the data set file we have provided! For marking purposes, it's important that your code runs correctly on the original data file.
#
# Some of the parts of this assignment build on the workflow from the first assignment and that part of the course, and so less detailed instructions are provided for this, as you should be able to implement this workflow now without low-level guidance. A substantial portion of the marks for this assignment are associated with making the right choices and executing this workflow correctly and efficiently. Make sure you have clean, readable code as well as producing outputs, since your coding will also count towards the marks (however, excessive commenting is discouraged and will lose marks, so aim for a modest, well-chosen amount of comments and text in outputs).
#
# This assignment can be solved using methods from [sklearn](https://scikit-learn.org/stable/index.html), [pandas](https://pandas.pydata.org/pandas-docs/stable/index.html), and [matplotlib](https://matplotlib.org/stable/index.html) as presented in the workshops. Other libraries should not be used (even though they might have nice functionality) and certain restrictions on sklearn functions will be made clear in the instruction text. You are expected to search and carefully read the documentation for functions that you use, to ensure you are using them correctly.

# %% [markdown]
# # Scenario
#
# A client approaches you to solve a machine learning problem for them.  They run a pathology lab that processes histological images for healthcare providers and they have created a product that measures the same features as in the *Wisconsin breast cancer data set* though using different acquisitions and processing methods. This makes their method much faster than existing ones, but it is also slightly noisier. They want to be able to diagnose *malignant* cancer (and distinguish them from *benign* growths) by employing machine learning techniques, and they have asked you to implement this for them.
#
# Their requirements are:
#  1) have at least a 95% probability of detecting malignant cancer when it is present;
#  2) have no more than 1 in 10 healthy cases (those with benign tumours) labelled as positive (malignant).
#
# They have hand-labelled 300 samples for you, which is all they have at the moment.
#
# Please follow the instructions below, which will vary in level of detail, as appropriate to the marks given.

# %% [markdown]
# ## 1. Investigate Dataset (10% = 3 marks)

# %%
# This code imports some libraries that you will need. 
# You should not need to modify it, though you are expected to make other imports later in your code.

# Python ≥3.5 is required
import sys
assert sys.version_info >= (3, 5)

# Common imports
import numpy as np
import time

# Pandas for overview
import pandas as pd

# Scikit-Learn ≥0.20 is required
import sklearn
assert sklearn.__version__ >= "0.20"
from sklearn import tree
from sklearn import svm
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import confusion_matrix

# Plot setup
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc('axes', labelsize=7)
mpl.rc('xtick', labelsize=6)
mpl.rc('ytick', labelsize=6)
mpl.rc('figure', dpi=240)
plt.close('all')

import seaborn as sns

# %% [markdown]
# ### 1.1 Load the dataset [0.5 marks]
# Do this from the csv file, `assignment2.csv`, as done in assignment 1 and workshops 2 and 3. Extract the feature names and label names for use later on.  Note that we will be treating the _malignant_ case as our _positive_ case, as this is the standard convention in medicine.
#
# **Print out some information (in text) about the data, to verify that the loading has worked and to get a feeling for what is present in the dataset and the range of the values.**
#
# **Also, graphically show the proportions of the labels in the whole dataset.**

# %%
# Your code here
data = pd.read_csv("/Users/malujie/Machine-learning/A2/assignment2.csv")

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   label                    300 non-null    object
#  1   mean radius              300 non-null    float64
#  2   mean texture             300 non-null    float64
#  3   mean perimeter           300 non-null    float64
#  4   mean area                300 non-null    float64
#  5   mean smoothness          300 non-null    float64
#  6   mean compactness         300 non-null    float64
#  7   mean concavity           300 non-null    float64
#  8   mean concave points      300 non-null    float64
#  9   mean symmetry            300 non-null    float64
#  10  mean fractal dimension   300 non-null    float64
#  11  radius error             300 non-null    float64
#  12  texture error            300 non-null    float64
# ...

# %%
data.head()
# Out:
#        label  mean radius  mean texture  mean perimeter   mean area  \
# 0  malignant    15.494654     15.902542      103.008265  776.437239
# 1  malignant    16.229871     18.785613      105.176755  874.712003
# 2  malignant    16.345671     20.114076      107.083804  872.563251
# 3  malignant    13.001009     19.876997       85.889775  541.281012
# 4  malignant    16.416060     17.397533      107.857386  891.516818
#
#    mean smoothness  mean compactness  mean concavity  mean concave points  \
# 0         0.104239          0.168660        0.170572             0.085668
# 1         0.091843          0.092548        0.081681             0.053670
# 2         0.099924          0.123799        0.128788             0.078310
# 3         0.113423          0.173069        0.146214             0.069574
# 4         0.097321          0.111530        0.125971             0.068575
#
#    mean symmetry  ...  worst radius  worst texture  worst perimeter  \
# ...

# %%
dummmy = data.hist(bins=40, figsize=(20,15))

# %% [markdown]
# ### 1.2 Visualise the dataset [1.5 marks]
#
# As this data is well curated by the client already, you do not need to worry about outliers, missing values or imputation in this case, but be aware that this is the exception, not the rule.
#
# To familiarise yourself with the nature and information contained in the data, display histograms for the data according to the following instructions:
#  - **display histograms** for each feature in the _mean_ group, but on _each_ histogram **have the two classes displayed together in one plot** (see example plot below and a code fragment to help you) - and note that your plot does not need to look exactly the example here;
#  - **repeat this** for the _standard error_ and _worst_ groups;
#  - make sure that in all cases you clearly label the plots and the classes in histograms.
#
# <center><img src=/Users/malujie/Machine-learning/A2/Example_Hist_Plot.png width="300" alt="Example plot of histogram"></center>

# %%
# Your code here
fig, axes = plt.subplots(6, 5, figsize=(20, 15))

# worst case
sns.histplot(data=data, x="worst radius", hue="label", bins=40, kde=True, ax=axes[0,0], edgecolor=None)
sns.histplot(data=data, x="worst texture", hue="label", bins=40, kde=True, ax=axes[0,1], edgecolor=None)
sns.histplot(data=data, x="worst perimeter", hue="label", bins=40, kde=True, ax=axes[0,2], edgecolor=None)
sns.histplot(data=data, x="worst area", hue="label", bins=40, kde=True, ax=axes[0,3], edgecolor=None)
sns.histplot(data=data, x="worst smoothness", hue="label", bins=40, kde=True, ax=axes[0,4], edgecolor=None)
sns.histplot(data=data, x="worst compactness", hue="label", bins=40, kde=True, ax=axes[1,0], edgecolor=None)
sns.histplot(data=data, x="worst concavity", hue="label", bins=40, kde=True, ax=axes[1,1], edgecolor=None)
sns.histplot(data=data, x="worst concave points", hue="label", bins=40, kde=True, ax=axes[1,2], edgecolor=None)
sns.histplot(data=data, x="worst symmetry", hue="label", bins=40, kde=True, ax=axes[1,3], edgecolor=None)
sns.histplot(data=data, x="worst fractal dimension", hue="label", bins=40, kde=True, ax=axes[1,4], edgecolor=None)

# standard case
sns.histplot(data=data, x="mean radius", hue="label", bins=40, kde=True, ax=axes[2,0], edgecolor=None)
sns.histplot(data=data, x="mean texture", hue="label", bins=40, kde=True, ax=axes[2,1], edgecolor=None)
sns.histplot(data=data, x="mean perimeter", hue="label", bins=40, kde=True, ax=axes[2,2], edgecolor=None)
sns.histplot(data=data, x="mean area", hue="label", bins=40, kde=True, ax=axes[2,3], edgecolor=None)
sns.histplot(data=data, x="mean smoothness", hue="label", bins=40, kde=True, ax=axes[2,4], edgecolor=None)
sns.histplot(data=data, x="mean compactness", hue="label", bins=40, kde=True, ax=axes[3,0], edgecolor=None)
sns.histplot(data=data, x="mean concavity", hue="label", bins=40, kde=True, ax=axes[3,1], edgecolor=None)
sns.histplot(data=data, x="mean concave points", hue="label", bins=40, kde=True, ax=axes[3,2], edgecolor=None)
sns.histplot(data=data, x="mean symmetry", hue="label", bins=40, kde=True, ax=axes[3,3], edgecolor=None)
sns.histplot(data=data, x="mean fractal dimension", hue="label", bins=40, kde=True, ax=axes[3,4], edgecolor=None)

# error case
sns.histplot(data=data, x="radius error", hue="label", bins=40, kde=True, ax=axes[4,0], edgecolor=None)
sns.histplot(data=data, x="texture error", hue="label", bins=40, kde=True, ax=axes[4,1], edgecolor=None)
sns.histplot(data=data, x="perimeter error", hue="label", bins=40, kde=True, ax=axes[4,2], edgecolor=None)
sns.histplot(data=data, x="area error", hue="label", bins=40, kde=True, ax=axes[4,3], edgecolor=None)
sns.histplot(data=data, x="smoothness error", hue="label", bins=40, kde=True, ax=axes[4,4], edgecolor=None)
sns.histplot(data=data, x="compactness error", hue="label", bins=40, kde=True, ax=axes[5,0], edgecolor=None)
sns.histplot(data=data, x="concavity error", hue="label", bins=40, kde=True, ax=axes[5,1], edgecolor=None)
sns.histplot(data=data, x="concave points error", hue="label", bins=40, kde=True, ax=axes[5,2], edgecolor=None)
sns.histplot(data=data, x="symmetry error", hue="label", bins=40, kde=True, ax=axes[5,3], edgecolor=None)
sns.histplot(data=data, x="fractal dimension error", hue="label", bins=40, kde=True, ax=axes[5,4], edgecolor=None)
# Out:
# <AxesSubplot:xlabel='fractal dimension error', ylabel='Count'>

# %% [markdown]
# ### 1.3 Ranking the features [0.5 marks]
#
# **Based on the histograms, which do you think are the 3 strongest features for discriminating between the classes?**

# %%
corr_matrix = data.corr()
# show label corr_matrix
corr_matrix.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_25d40_row0_col0, #T_25d40_row0_col2, #T_25d40_row1_col1, #T_25d40_row2_col0, #T_25d40_row2_col2, #T_25d40_row3_col3, #T_25d40_row4_col4, #T_25d40_row5_col5, #T_25d40_row6_col6, #T_25d40_row7_col7, #T_25d40_row8_col8, #T_25d40_row9_col9, #T_25d40_row10_col10, #T_25d40_row11_col11, #T_25d40_row12_col12, #T_25d40_row13_col13, #T_25d40_row14_col14, #T_25d40_row15_col15, #T_25d40_row16_col16, #T_25d40_row17_col17, #T_25d40_row18_col18, #T_25d40_row19_col19, #T_25d40_row20_col20, #T_25d40_row21_col21, #T_25d40_row22_col22, #T_25d40_row23_col23, #T_25d40_row24_col24, #T_25d40_row25_col25, #T_25d40_row26_col26, #T_25d40_row27_col27, #T_25d40_row28_col28, #T_25d40_row29_col29 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_25d40_row0_col1, #T_25d40_row9_col14, #T_25d40_row14_col18, #T_25d40_row26_col4 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# ...

# %% [markdown]
# **Your answer here :**
#
# - worst radius
# - worst perimeter
# - worst concave points

# %% [markdown]
# ### 1.4 Splitting the dataset [0.5 marks]
#
# Split the dataset into appropriate subsets. You must choose what the subsets are and how big they are. However, we want to make sure the proportion of the two classes is consistent across all datasets, so use the _stratify_ option, as used in workshops 5 and 6. Verify the size and label distribution in each dataset.

# %%
# replace malignant to 0 and benign to 1
# malignant --> negative --> 0
# benign --> positive --> 1
data = data.replace(['benign', 'malignant'], [1, 0])

# %%
# Your code here
from sklearn.model_selection import train_test_split

xarray = data.drop(['label'], axis=1)
yarray = data['label']
print(xarray.shape)
print(yarray.shape)

fullarray = np.concatenate((xarray,yarray.values.reshape(-1,1)),axis=1)
print(fullarray.shape)
# Out:
# (300, 30)
# (300,)
# (300, 31)

# %%
from sklearn.model_selection import train_test_split

bigtrain_set, test_set = train_test_split(fullarray, test_size=0.2, random_state=42, stratify=fullarray[:,-1])
train_set, val_set = train_test_split(bigtrain_set, test_size=0.2, random_state=42, stratify=bigtrain_set[:,-1])

# %%
X_train = train_set[:,:-1]
y_train = train_set[:,-1]
X_test = test_set[:,:-1]
y_test = test_set[:,-1]
X_val = val_set[:,:-1]
y_val = val_set[:,-1]
print(f'Shapes are {[X_train.shape,y_train.shape,X_test.shape,y_test.shape,X_val.shape,y_val.shape]}')
# Out:
# Shapes are [(192, 30), (192,), (60, 30), (60,), (48, 30), (48,)]

# %%
print(np.mean(y_train),np.mean(y_test),np.mean(y_val))
# Out:
# 0.5104166666666666 0.5166666666666667 0.5208333333333334

# %% [markdown]
# ## 2. Build, Train and Optimise Classifiers (60% = 18 marks)

# %% [markdown]
# ### 2.1 Pipeline [0.5 marks]
# **Build a pre-processing pipeline** that includes imputation (as even though we don't strictly need it here it is a good habit to always include it) and other appropriate pre-processing.

# %%
# Your code here
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer

preproc_pl = Pipeline([ ('imputer', SimpleImputer(strategy="median")), ('scaler', StandardScaler())])

# %% [markdown]
# ### 2.2 Baseline measurements [1.5 marks]
#
# For our classification task we will consider **three simple baseline cases**:
# 1) predicting all samples to be negative (class 1)
# 2) predicting all samples to be positive (class 2)
# 3) making a random prediction for each sample with equal probability for each class
#
# **For each case measure and display the following metrics:**
#  - balanced accuracy
#  - recall
#  - precision
#  - auc
#  - f1score
#  - fbeta_score with beta=0.1
#  - fbeta_score with beta=10
#
# Code is given below for the latter metrics (all metrics are discussed in lecture 4 and many are in workshop 4).
#
# Also **calculate and display the confusion matrix** for each baseline case, using a heatmap and numbers (as in workshop 4).

# %%
from sklearn.metrics import fbeta_score, make_scorer

f10_scorer = make_scorer(fbeta_score, beta=10)
f01_scorer = make_scorer(fbeta_score, beta=0.1)

def f10_score(yt,yp):
    return fbeta_score(yt, yp, beta=10)

def f01_score(yt,yp):
    return fbeta_score(yt, yp, beta=0.1)

# %%
# Your code here
from sklearn import metrics
from sklearn.metrics import f1_score
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_score, recall_score

# class 1 --> negative
print("Class 1 --> negative")
y_val_pred = np.zeros(y_val.shape[0])

# accuracy
acc = balanced_accuracy_score(y_true = y_val, y_pred = y_val_pred)
print(f'Accuracy is {acc}')

# prec and recall
prec = precision_score(y_true = y_val, y_pred = y_val_pred, zero_division=0)  # zero_division=0
recl = recall_score(y_true = y_val, y_pred = y_val_pred)
print(f'Precision & Recall are {prec} and {recl}')

# auc
fpr, tpr, thresholds = metrics.roc_curve(y_val, y_val_pred, pos_label=1)
auc = metrics.auc(fpr, tpr)
print(f'AUC is {auc}')

#f1 score
f1 = f1_score(y_val, y_val_pred, zero_division=1)
print(f'F1 score is {f1}')

# f0.1 score
f01 = f01_score(y_val, y_val_pred)
print(f'F0.1 score is {f01}')

# f10 score
f_score = f10_score(y_val, y_val_pred)
print(f'F10 score is {f_score}')

# display the confusion matrix
cmat = confusion_matrix(y_true=y_val, y_pred=y_val_pred, normalize='all')
sns.heatmap(cmat,annot=True) 
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Normalised Confusion Matrix')
plt.show()
# Out:
# Class 1 --> negative
# Accuracy is 0.5
# Precision & Recall are 0.0 and 0.0
# AUC is 0.5
# F1 score is 0.0
# F0.1 score is 0.0
# F10 score is 0.0

# %%
# class 2 --> positive
print("Class 2 --> postive")
y_val_pred = np.ones(y_val.shape[0])

# accuracy
acc = balanced_accuracy_score(y_true = y_val, y_pred = y_val_pred)
print(f'Accuracy is {acc}')

# prec and recall
prec = precision_score(y_true = y_val, y_pred = y_val_pred)
recl = recall_score(y_true = y_val, y_pred = y_val_pred)
print(f'Precision & Recall are {prec} and {recl}')

# auc
fpr, tpr, thresholds = metrics.roc_curve(y_val, y_val_pred, pos_label=1)
auc = metrics.auc(fpr, tpr)
print(f'AUC is {auc}')

# f1 score
f1 = f1_score(y_val, y_val_pred)
print(f'F1 score is {f1}')

# f0.1 score
f01 = f01_score(y_val, y_val_pred)
print(f'F0.1 score is {f01}')

# f10 score
f_score = f10_score(y_val, y_val_pred)
print(f'F10 score is {f_score}')

# display the confusion matrix
cmat = confusion_matrix(y_true=y_val, y_pred=y_val_pred, normalize='all')
sns.heatmap(cmat,annot=True) 
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Normalised Confusion Matrix')
plt.show()
# Out:
# Class 2 --> postive
# Accuracy is 0.5
# Precision & Recall are 0.5208333333333334 and 1.0
# AUC is 0.5
# F1 score is 0.684931506849315
# F0.1 score is 0.5233160621761659
# F10 score is 0.9909733124018839

# %%
# class 3 --> random
print("Class 3 --> random")
y_val_pred = np.random.randint(0,2,y_val.shape[0])

# accuracy
acc = balanced_accuracy_score(y_true = y_val, y_pred = y_val_pred)
print(f'Accuracy is {acc}')

# prec and recall
prec = precision_score(y_true = y_val, y_pred = y_val_pred, zero_division=1)
recl = recall_score(y_true = y_val, y_pred = y_val_pred)
print(f'Precision & Recall are {prec} and {recl}')

# auc
fpr, tpr, thresholds = metrics.roc_curve(y_val, y_val_pred, pos_label=1)
auc = metrics.auc(fpr, tpr)
print(f'AUC is {auc}')

# f1 score
f1 = f1_score(y_val, y_val_pred)
print(f'F1 score is {f1}')

# f0.1 score
f01 = f01_score(y_val, y_val_pred)
print(f'F0.1 score is {f01}')

# f10 score
f_score = f10_score(y_val, y_val_pred)
print(f'F10 score is {f_score}') 

# display the confusion matrix
cmat = confusion_matrix(y_true=y_val, y_pred=y_val_pred, normalize='all')
sns.heatmap(cmat,annot=True) 
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Normalised Confusion Matrix')
plt.show()
# Out:
# Class 3 --> random
# Accuracy is 0.4756521739130435
# Precision & Recall are 0.5 and 0.56
# AUC is 0.4756521739130435
# F1 score is 0.5283018867924528
# F0.1 score is 0.5005309734513275
# F10 score is 0.5593354430379747

# %% [markdown]
# ### 2.3 Choose a performance metric [0.5 marks]
#
# Based on the above baseline tests and the client's requirements, **choose a performance metric** to use for evaluating/driving your machine learning methods.  **Give a reason for your choice.**

# %% [markdown]
# **Your answer here**
# - Accuracy_score computes subset accuracy;
# - Precision: TP/(TP+FP);
# - Recall: TP/(TP+FN);
# - TPR = recall = TP/(TP+FN);
# - FPR = 1 - TN/(TN+FP);
# - AUC is depend on TPR and FPR. So larger AUC means better.
# - F1,F01,F10 score depends on precision and recall.
#
# All in all, I think Accuracy is the best. Because Accuracy would not influenced a lot by extreme data.

# %% [markdown]
# ### 2.4 SGD baseline [1 mark]
#
# For a stronger baseline, **train and evaluate** the Stochastic Gradient Descent classifier (as seen in workshop 5). For this baseline case use the default settings for all the hyperparameters.

# %%
from sklearn.linear_model import SGDClassifier
from sklearn.metrics import accuracy_score, hinge_loss

def sgdfn(nsamp, learnrate):
    sgd = SGDClassifier(warm_start=True, learning_rate='constant', eta0=learnrate)
    X_trainp = preproc_pl.fit_transform(X_train)
    X_valp = preproc_pl.fit_transform(X_val)
    res=[]

    for n in range(1000):
        sgd.partial_fit(X_trainp[0:50],y_train[0:50],classes=[0,1])
        y_val_pred = sgd.predict(X_valp)
        sgd_acc = accuracy_score(y_val,y_val_pred)
        sgd_loss = hinge_loss(y_val,y_val_pred)
        res += [[sgd_acc,sgd_loss]]

    res = np.array(res)

    plt.figure(figsize=(10,4))
    plt.subplot(121)
    plt.plot(res[:,0])
    plt.title('Accuracy')
    plt.xlabel('Epoch')
    plt.subplot(122)
    plt.plot(res[:,1])
    plt.title('Loss')
    plt.xlabel('Epoch')
    plt.show()

    return [res[-1,0],res[-1,1]]

# %%
ntrain = X_train.shape[0]
sgdfn(ntrain,1e-5)
# Out:
# [0.9791666666666666, 0.5]

# %%
# Your code here
from sklearn.linear_model import SGDClassifier

sgd_pl = Pipeline([ ('preproc',preproc_pl), ('sgd',SGDClassifier(loss='log', eta0=1e-05)) ])
sgd_pl.fit(X_train,y_train)
y_val_pred = sgd_pl.predict(X_val)

b_acc = balanced_accuracy_score(y_val,y_val_pred)
print(f'Balance accuracy is {b_acc}')

acc = accuracy_score(y_val,y_val_pred)
print(f'Accuracy is {acc}')
# Out:
# Balance accuracy is 0.96
# Accuracy is 0.9583333333333334

# %% [markdown]
# ### 2.5 Confusion matrix [1 mark]
#
# Calculate and display the normalized version of the confusion matrix.  From this **calculate the _probability_ that a sample from a person with a malignant tumour is given a result that they do not have cancer.  Which of the client's two criteria does this relate to, and is this baseline satisfying this criterion or not?**

# %%
# Your code here
cmat = confusion_matrix(y_true=y_val, y_pred=y_val_pred, normalize='all')
sns.heatmap(cmat,annot=True)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Normalised Confusion Matrix')
plt.show()

# %% [markdown]
# Actually do not have cancer --> positive
#
# A sample from a person with a malignant tumour is given a result that they do not have cancer --> FP
#
# The probability is 0 (FP).

# %% [markdown]
# ### 2.6 Main classifier [11 marks]
#
# **Train and optimise the hyperparameters** to give the best performance for **each of the following classifiers**:
#  - KNN (K-Nearest Neighbour) classifier
#  - Decision tree classifier
#  - Support vector machine classifier
#  - SGD classifier
#
# Follow best practice as much as possible here. You must make all the choices and decisions yourself, and strike a balance between computation time and performance.
#
# You can use any of the sci-kit learn functions in sklearn.model_selection.cross* and anything used in workshops 3, 4, 5 and 6. Other hyper-parameter optimisation functions apart from these cannot be used (even if they are good and can be part of best practice in other situations - for this assignment everyone should assume they only have very limited computation resources and limit themselves to these functions).
#
# **Display the performance of the different classifiers and the optimised hyperparameters.**
#
# **Based on these results, list the best 3 classifiers and indicate if you think any perform equivalently.**

# %% [markdown]
# **KNN classifier**

# %%
# Your code here
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import cross_validate
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.model_selection import GridSearchCV
import time

start = time.time()

knn_pl = Pipeline([ ('preproc',preproc_pl), ('knn',KNeighborsClassifier()) ])
knn_pl.fit(X_train,y_train)
y_knn_pred = knn_pl.predict(X_val)

# get original acc
b_acc = balanced_accuracy_score(y_val,y_knn_pred)
acc = accuracy_score(y_val,y_knn_pred)
print("orignal accuracy:", acc)
print("balanced accuracy:", b_acc)

print("--------------------------------------")

parameters = {'knn__n_neighbors':[1,3,5,7,9]}
gridcv = GridSearchCV(knn_pl, parameters, cv=5, scoring='neg_root_mean_squared_error')
gridcv.fit(X_train, y_train)
print(f'Best score is {-gridcv.best_score_} for best params of {gridcv.best_params_}')  



knn_pl_improve = Pipeline([ ('preproc',preproc_pl), 
                            ('knn',KNeighborsClassifier(n_neighbors=3)) ])
knn_pl_improve.fit(X_train,y_train)
y_knn_pred = knn_pl_improve.predict(X_val)
y_knn_test_pred = knn_pl_improve.predict(X_test)
y_knn_train_pred = knn_pl_improve.predict(X_train)

print("--------------------------------------")

# get improve acc
acc = balanced_accuracy_score(y_val,y_knn_pred)
print("improved accuracy:", acc)

# prec and recall
prec = precision_score(y_true = y_val, y_pred = y_knn_pred)
recl = recall_score(y_true = y_val, y_pred = y_knn_pred)
print(f'Precision & Recall are {prec} and {recl}')

# auc
fpr, tpr, thresholds = metrics.roc_curve(y_val, y_knn_pred, pos_label=1)
auc = metrics.auc(fpr, tpr)
print(f'AUC is {auc}')

# f1 score
f1 = f1_score(y_val, y_knn_pred)
print(f'F1 score is {f1}')

# f0.1 score
f01 = f01_score(y_val, y_knn_pred)
print(f'F0.1 score is {f01}')

# f10 score
f_score = f10_score(y_val, y_knn_pred)
print(f'F10 score is {f_score}') 

end = time.time()
 
print("--------------------------------------")

print("The time of execution of above program is :", end-start)
# Out:
# orignal accuracy: 0.9583333333333334
# balanced accuracy: 0.96
# --------------------------------------
# Best score is 0.17939500759581523 for best params of {'knn__n_neighbors': 3}
# --------------------------------------
# improved accuracy: 0.98
# Precision & Recall are 1.0 and 0.96
# AUC is 0.98
# F1 score is 0.9795918367346939
# F0.1 score is 0.9995876288659794
# F10 score is 0.9603803486529319
# --------------------------------------
# The time of execution of above program is : 0.16628575325012207

# %% [markdown]
# **Decision Tree classifier**

# %%
from sklearn.tree import DecisionTreeClassifier, plot_tree

start = time.time()

clf_pl = Pipeline([ ('preproc',preproc_pl), ('clf', DecisionTreeClassifier(random_state=20)) ])
clf_pl.fit(X_train,y_train)
y_clf_pred = clf_pl.predict(X_val)

# get original acc
b_acc = balanced_accuracy_score(y_val,y_clf_pred)
acc = accuracy_score(y_val,y_clf_pred)
print("orignal accuracy:", acc)
print("balanced accuracy:", b_acc)

print("--------------------------------------")

parameters = {'clf__random_state':[0,3,5,10,30,50]}
gridcv = GridSearchCV(clf_pl, parameters, cv=5, scoring='neg_root_mean_squared_error')
gridcv.fit(X_train, y_train)
print(f'Best score is {-gridcv.best_score_} for best params of {gridcv.best_params_}')  

print("--------------------------------------")

clf_pl_improve = Pipeline([ ('preproc',preproc_pl),
                            ('clf',DecisionTreeClassifier(random_state=50)) ])
clf_pl_improve.fit(X_train,y_train)
y_clf_pred = clf_pl_improve.predict(X_val)
y_clf_test_pred = clf_pl_improve.predict(X_test)
y_clf_train_pred = clf_pl_improve.predict(X_train)

# get improve acc
acc = balanced_accuracy_score(y_val,y_clf_pred)
print("improved accuracy:", acc)

# prec and recall
prec = precision_score(y_true = y_val, y_pred = y_clf_pred)
recl = recall_score(y_true = y_val, y_pred = y_clf_pred)
print(f'Precision & Recall are {prec} and {recl}')

# auc
fpr, tpr, thresholds = metrics.roc_curve(y_val, y_clf_pred, pos_label=1)
auc = metrics.auc(fpr, tpr)
print(f'AUC is {auc}')

# f1 score
f1 = f1_score(y_val, y_clf_pred)
print(f'F1 score is {f1}')

# f0.1 score
f01 = f01_score(y_val, y_clf_pred)
print(f'F0.1 score is {f01}')

# f10 score
f_score = f10_score(y_val, y_clf_pred)
print(f'F10 score is {f_score}') 

end = time.time()
 
print("--------------------------------------")

print("The time of execution of above program is :", end-start)
# Out:
# orignal accuracy: 0.9583333333333334
# balanced accuracy: 0.96
# --------------------------------------
# Best score is 0.2731614603758084 for best params of {'clf__random_state': 50}
# --------------------------------------
# improved accuracy: 0.98
# Precision & Recall are 1.0 and 0.96
# AUC is 0.98
# F1 score is 0.9795918367346939
# F0.1 score is 0.9995876288659794
# F10 score is 0.9603803486529319
# --------------------------------------
# The time of execution of above program is : 0.16814374923706055

# %% [markdown]
# **Support vector machine classifier**

# %%
from sklearn.svm import SVC

start = time.time()

svm_pl = Pipeline([('preproc',preproc_pl), ('svc',SVC(kernel='poly'))])
svm_pl.fit(X_train,y_train)
y_svm_pred = svm_pl.predict(X_val)

# get original acc
b_acc = balanced_accuracy_score(y_val,y_svm_pred)
acc = accuracy_score(y_val,y_svm_pred)
print("orignal accuracy:", acc)
print("balanced accuracy:", b_acc)

print("--------------------------------------")

parameters = {'svc__kernel':['linear','poly','rbf'], 'svc__random_state':[0,1,10,20,30,40,50]}
gridcv = GridSearchCV(svm_pl, parameters, cv=5, scoring='neg_root_mean_squared_error')
gridcv.fit(X_train, y_train)
print(f'Best score is {-gridcv.best_score_} for best params of {gridcv.best_params_}')  

print("--------------------------------------")

svm_pl_improve = Pipeline([('preproc',preproc_pl),
                            ('svc',SVC(kernel='linear',random_state=0))])
svm_pl_improve.fit(X_train,y_train)
y_svm_pred = svm_pl_improve.predict(X_val)
y_svm_test_pred = svm_pl_improve.predict(X_test)
y_svm_train_pred = svm_pl_improve.predict(X_train)

# get improve acc
acc = balanced_accuracy_score(y_val,y_svm_pred)
print("improved accuracy:", acc)

# prec and recall
prec = precision_score(y_true = y_val, y_pred = y_svm_pred)
recl = recall_score(y_true = y_val, y_pred = y_svm_pred)
print(f'Precision & Recall are {prec} and {recl}')

# auc
fpr, tpr, thresholds = metrics.roc_curve(y_val, y_svm_pred, pos_label=1)
auc = metrics.auc(fpr, tpr)
print(f'AUC is {auc}')

# f1 score
f1 = f1_score(y_val, y_svm_pred)
print(f'F1 score is {f1}')

# f0.1 score
f01 = f01_score(y_val, y_svm_pred)
print(f'F0.1 score is {f01}')

# f10 score
f_score = f10_score(y_val, y_svm_pred)
print(f'F10 score is {f_score}') 

end = time.time()
 
print("--------------------------------------")

print("The time of execution of above program is :", end-start)
# Out:
# orignal accuracy: 0.9791666666666666
# balanced accuracy: 0.9782608695652174
# --------------------------------------
# Best score is 0.12066506368207157 for best params of {'svc__kernel': 'linear', 'svc__random_state': 0}
# --------------------------------------
# improved accuracy: 1.0
# Precision & Recall are 1.0 and 1.0
# AUC is 1.0
# F1 score is 1.0
# F0.1 score is 1.0
# F10 score is 1.0
# --------------------------------------
# The time of execution of above program is : 0.5081601142883301

# %% [markdown]
# **SGD classifier**

# %%
# sgd classifier
sgd_pl = Pipeline([ ('preproc',preproc_pl), ('sgd',SGDClassifier(loss='log')) ])
sgd_pl.fit(X_train,y_train)
y_sgd_pred = sgd_pl.predict(X_val)
y_sgd_prob = sgd_pl.predict_proba(X_val)

# get original acc
b_acc = balanced_accuracy_score(y_val,y_sgd_pred)
acc = accuracy_score(y_val,y_sgd_pred)
print("orignal accuracy:", acc)
print("balanced accuracy:", b_acc)



parameters = {'sgd__eta0':[1,0.1,0.01,0.001,0.0001,0.00001], 'sgd__loss':['log','hinge']}
gridcv = GridSearchCV(sgd_pl, parameters, cv=5, scoring='neg_root_mean_squared_error')
gridcv.fit(X_train, y_train)
print(f'Best score is {-gridcv.best_score_} for best params of {gridcv.best_params_}')
# Out:
# orignal accuracy: 0.9791666666666666
# balanced accuracy: 0.98
# Best score is 0.1370175399981711 for best params of {'sgd__eta0': 0.01, 'sgd__loss': 'log'}

# %%
start1 = time.time()

sgd_pl_improve = Pipeline([ ('preproc',preproc_pl),
                            ('sgd',SGDClassifier(eta0=0.01,loss='log',early_stopping=False)) ])
sgd_pl_improve.fit(X_train,y_train)
y_sgd_pred = sgd_pl_improve.predict(X_val)
y_sgd_test_pred = sgd_pl_improve.predict(X_test)
y_sgd_train_pred = sgd_pl_improve.predict(X_train)

print("---- first test ----")

# get improve acc
acc = balanced_accuracy_score(y_val,y_sgd_pred)
print("improved accuracy:", acc)

# prec and recall
prec = precision_score(y_true = y_val, y_pred = y_sgd_pred)
recl = recall_score(y_true = y_val, y_pred = y_sgd_pred)
print(f'Precision & Recall are {prec} and {recl}')

# auc
fpr, tpr, thresholds = metrics.roc_curve(y_val, y_sgd_pred, pos_label=1)
auc = metrics.auc(fpr, tpr)
print(f'AUC is {auc}')

# f1 score
f1 = f1_score(y_val, y_sgd_pred)
print(f'F1 score is {f1}')

# f0.1 score
f01 = f01_score(y_val, y_sgd_pred)
print(f'F0.1 score is {f01}')

# f10 score
f_score = f10_score(y_val, y_sgd_pred)
print(f'F10 score is {f_score}') 

end1 = time.time()
 
print("--------------------------------------")

print("The time of execution of above program is :", end1-start1)
# Out:
# ---- first test ----
# improved accuracy: 0.98
# Precision & Recall are 1.0 and 0.96
# AUC is 0.98
# F1 score is 0.9795918367346939
# F0.1 score is 0.9995876288659794
# F10 score is 0.9603803486529319
# --------------------------------------
# The time of execution of above program is : 0.013234138488769531

# %%
sgd_pl_improve = Pipeline([ ('preproc',preproc_pl),
                            ('sgd',SGDClassifier(eta0=0.01,loss='log',early_stopping=False)) ])
sgd_pl_improve.fit(X_train,y_train)
y_sgd_pred = sgd_pl_improve.predict(X_val)
y_sgd_test_pred = sgd_pl_improve.predict(X_test)
y_sgd_train_pred = sgd_pl_improve.predict(X_train)

print("---- second test ----")

# get improve acc
acc = balanced_accuracy_score(y_val,y_sgd_pred)
print("improved accuracy:", acc)

# prec and recall
prec = precision_score(y_true = y_val, y_pred = y_sgd_pred)
recl = recall_score(y_true = y_val, y_pred = y_sgd_pred)
print(f'Precision & Recall are {prec} and {recl}')

# auc
fpr, tpr, thresholds = metrics.roc_curve(y_val, y_sgd_pred, pos_label=1)
auc = metrics.auc(fpr, tpr)
print(f'AUC is {auc}')

# f1 score
f1 = f1_score(y_val, y_sgd_pred)
print(f'F1 score is {f1}')

# f0.1 score
f01 = f01_score(y_val, y_sgd_pred)
print(f'F0.1 score is {f01}')

# f10 score
f_score = f10_score(y_val, y_sgd_pred)
print(f'F10 score is {f_score}')
# Out:
# ---- second test ----
# improved accuracy: 0.96
# Precision & Recall are 1.0 and 0.92
# AUC is 0.96
# F1 score is 0.9583333333333334
# F0.1 score is 0.9991397849462366
# F10 score is 0.9207292905271502

# %% [markdown]
# **Your answer here:**
#
# About time cost:
#
# - KNN model: 0.27
# - dt  model: 0.19
# - SVM model: 0.60
# - SGD model: 0.02
#
# We can see that KNN and dt model works better in time cost.
#
# ***
#
# About Accuracy:
#
# - KNN model: 0.98
# - DT  model: 0.98 --> same as KNN model
# - SVM model: 1.00
# - SGD model: 1.00 / 0.98 / 0.96
#
#
# We can see that SGD model is not stable  -->  return different accuracy by same params.
#
# Decision Tree and KNN model shows the same accuracy score(0.98).
#
# SVM model shows the highest accuracy which is 1.0.
#
# My selection is **KNN model, Decision Tree model and the SVM model**.

# %% [markdown]
# ### 2.7 Model selection [1 mark]
#
# **Choose the best classifier** (as seen in workshops 3 to 6) and give details of your hyperparameter settings. **Explain the reason for your choice.**

# %%
# get acc --> KNN Classifier
acc1 = balanced_accuracy_score(y_test,y_knn_test_pred)
acc2 = balanced_accuracy_score(y_train,y_knn_train_pred)
print("KNN --> test accuracy:", acc1, " , and the train accuracy:", acc2)

# get acc --> Decision Tree Classifier
acc1 = balanced_accuracy_score(y_test,y_clf_test_pred)
acc2 = balanced_accuracy_score(y_train,y_clf_train_pred)
print("dt  --> test accuracy:", acc1, " , and the train accuracy:", acc2)

# get acc --> SVM Classifier
acc1 = balanced_accuracy_score(y_test,y_svm_test_pred)
acc2 = balanced_accuracy_score(y_train,y_svm_train_pred)
print("SVM --> test accuracy:", acc1, " , and the train accuracy:", acc2)
# Out:
# KNN --> test accuracy: 0.8815350389321468  , and the train accuracy: 0.97405557967868
# dt  --> test accuracy: 0.9149054505005562  , and the train accuracy: 1.0
# SVM --> test accuracy: 0.9482758620689655  , and the train accuracy: 0.9893617021276595

# %% [markdown]
# **About overfitting and underfitting**
#
# - We can see that KNN Classifier, Decision Tree Classifier, SVM Classifier all shows overfitting because a huge difference between test accuracy and the train accuracy.
# - SGD Classifier works good in this.
#
# However, SGD Classifier is not stable. So I would choose SVM Classifier.

# %% [markdown]
# SVM model is the best model with **kernel: linear, random_state: 0**.

# %% [markdown]
# ### 2.8 Final performance [1.5 marks]
#
# **Calculate and display an unbiased performance measure that you can present to the client.**
#
# **Is your chosen classifier underfitting or overfitting?**
#
# **Does your chosen classifier meet the client's performance criteria?**

# %%
# draw confusion matrix of SVM
cmat = confusion_matrix(y_true=y_train, y_pred=y_svm_train_pred, normalize='all')
sns.heatmap(cmat,annot=True)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix --> train')
plt.show()

cmat = confusion_matrix(y_true=y_test, y_pred=y_svm_test_pred, normalize='all')
sns.heatmap(cmat,annot=True)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix --> test')
plt.show()

cmat = confusion_matrix(y_true=y_val, y_pred=y_svm_pred, normalize='all')
sns.heatmap(cmat,annot=True)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix --> val')
plt.show()

# %% [markdown]
# **Your answers here**
#
# **About overfitting and underfitting**
#
# - We can see that KNN Classifier, Decision Tree Classifier, SVM Classifier all shows overfitting because a huge difference between test accuracy and the train accuracy.
# - SGD Classifier works good in this.
#
# However, SGD Classifier is not stable. So I would choose SVM Classifier.

# %% [markdown]
# ***

# %% [markdown]
# **About meeting the client's performance criteria**
#
# 1) have at least a 95% probability of detecting malignant cancer when it is present;
#
# - Not reached. SVM accuracy only have 94.82758620689655% which is lower than 95%.
#
# 2) have no more than 1 in 10 healthy cases (those with benign tumours) labelled as positive (malignant).
#
# -  Reached. Lower than 10%.

# %% [markdown]
# ## 3. Decision Boundaries (15% = 4.5 marks)

# %% [markdown]
# ### 3.1 Rank features [1 mark]
#
# Although it is only possible to know the true usefulness of a feature when you've combined it with others in a machine learning method, it is still helpful to have some measure for how discriminative each feature is on its own.  One common method for doing this is to calculate a T-score (often used in statistics, and in the LDA machine learning method) for each feature.
#
# The formula for the T-score is (mean(x2) - mean(x1))/(0.5*(stddev(x2) + stddev(x1))), where x1 and x2 are the datasets corresponding to the two classes. Large values for the T-score (either positive or negative) indicate discriminative ability.
#
# **Calculate the T-score for each feature and print out the best 4 features according to this score.**

# %%
xarray = data.drop(['label'], axis=1)
yarray = data['label']

y_mean = np.mean(yarray)
y_std = np.std(yarray)

X_mean = np.mean(xarray, axis=0)
X_std = np.std(xarray, axis=0)

T_score = (X_mean - y_mean)/(0.5*(X_std + y_std))

T_score = np.abs(T_score)
max_4 = T_score.nlargest(4)

max_4
# Out:
# mean perimeter     19.547644
# mean texture       18.168617
# worst texture      17.774002
# worst perimeter    16.650057
# dtype: float64

# %% [markdown]
# ### 3.2 Visualise decision boundaries [2.5 marks]
#
# **Display the decision boundaries** for each pair of features from the best 4 chosen above.  You can use the functions below to help (taken from workshop 6).
#
# Instead of using the simple mean as the input for `xmean` in `plot_contours`, use the following: 0.5*(mean(x1) + mean(x2)), where x1 and x2 are the data associated with the two classes.  This way of calculating a "mean" point takes into account any imbalance between the classes.

# %%
def make_meshgrid(x, y, ns=100):
    """Create a mesh of points to plot in

    Parameters
    ----------
    x: data to base x-axis meshgrid on (only min and max used)
    y: data to base y-axis meshgrid on (only min and max used)
    ns: number of steps in grid, optional

    Returns
    -------
    xx, yy : ndarray
    """
    x_min, x_max = x.min(), x.max()
    y_min, y_max = y.min(), y.max()
    hx = (x_max - x_min)/ns
    hy = (y_max - y_min)/ns
    xx, yy = np.meshgrid(np.arange(x_min, x_max + hx, hx), np.arange(y_min, y_max + hy, hy))
    return xx, yy

# %%
def plot_contours(clf, xx, yy, xmean, n1, n2, **params):
    """Plot the decision boundaries for a classifier.

    Parameters
    ----------
    clf: a classifier
    xx: meshgrid ndarray
    yy: meshgrid ndarray
    xmean : 1d array of mean values (to populate constant features with)
    n1, n2: index numbers of features that change (for xx and yy)
    params: dictionary of params to pass to contourf, optional
    """
    # The following lines makes an MxN matrix to pass to the classifier (# samples x # features)
    # It does this by multiplying Mx1 and 1xN matrices, where the former is filled with 1's
    #  where M is the number of grid points in xx and N is the number of features in xmean
    #  It is done in such a way that the xmean vector is replaced in each row
    fullx = np.ones((xx.ravel().shape[0],1)) * np.reshape(xmean,(1,-1))
    fullx[:,n1] = xx.ravel()
    fullx[:,n2] = yy.ravel()
    Z = clf.predict(fullx)
    Z = Z.reshape(xx.shape)
    out = plt.contourf(xx, yy, Z, **params)
    return out

# %%
# split train data with negative and positive labels
neg_train = X_train[y_train == 0]
pos_train = X_train[y_train == 1]

# %%
neg_mean = np.mean(neg_train, axis=0)
pos_mean = np.mean(pos_train, axis=0)

xmean = 0.5 * (neg_mean + pos_mean)

# %%
def draw_db(n0, n1):
    x10, x90 = np.percentile(X_train[:,n0], [10, 90])
    y10, y90 = np.percentile(X_train[:,n1], [10, 90])
    xx, yy = make_meshgrid(np.array([x10, x90]), np.array([y10, y90]), 500)

    plot_contours(svm_pl_improve, xx, yy, xmean, n0, n1, alpha=0.8, cmap=plt.cm.coolwarm)

    plt.scatter(X_train[:,n0], X_train[:,n1], c=y_train, cmap=plt.cm.coolwarm, s=20, edgecolors="k")
    plt.scatter(X_val[:,n0], X_val[:,n1], c=y_val, cmap=plt.cm.coolwarm, s=20, edgecolors="k", marker='s')

    plt.xlim(xx.min(), xx.max())
    plt.ylim(yy.min(), yy.max())
    plt.xlabel(f"Feature {n0}")
    plt.ylabel(f"Feature {n1}")
    plt.title("Decision Boundary")

    plt.show()

# %%
n0 = list(data.columns).index('worst perimeter') 
n1 = list(data.columns).index('worst texture')
n2 = list(data.columns).index('mean perimeter') 
n3 = list(data.columns).index('mean texture')


draw_db(n0, n1)
draw_db(n0, n2)
draw_db(n0, n3)
draw_db(n1, n2)
draw_db(n1, n3)
draw_db(n2, n3)

# %% [markdown]
# ### 3.3 Interpretation [1 mark]
#
# From the decision boundaries displayed above, **would you expect the method to extrapolate well or not**?  Give reasons for your answer.

# %% [markdown]
# **Your answer here**
#
# It is not what I expected. Because most of red points are not in the red area.

# %% [markdown]
# ## 4. Second Round (15% = 4.5 marks)
#
# After presenting your initial results to the client they come back to you and say that they have done some financial analysis and it would save them a lot of time and money if they did not have to analyse every cell, which is needed to get the "worst" features. Instead, they can quickly get accurate estimates for the "mean" and "standard error" features from a much smaller, randomly selected set of cells.
#
# They ask you to **give them a performance estimate for the same problem, but without using any of the "worst" features.**

# %% [markdown]
# ### 4.1 New estimate [3.5 marks]
#
# **Calculate an unbiased performance estimate** for this new problem, as requested by the client.

# %%
# Your code here
data = pd.read_csv("/Users/malujie/Machine-learning/A2/assignment2.csv")

# delete last 10 columns --> delete woest case
data = data.drop(data.columns[-10:], axis=1)

# replace malignant to 0 and benign to 1
data = data.replace(['benign', 'malignant'], [1, 0])

from sklearn.model_selection import train_test_split

xarray = data.drop(['label'], axis=1)
yarray = data['label']
print(xarray.shape)
print(yarray.shape)

fullarray = np.concatenate((xarray,yarray.values.reshape(-1,1)),axis=1)
print(fullarray.shape)

from sklearn.model_selection import train_test_split

bigtrain_set, test_set = train_test_split(fullarray, test_size=0.2, random_state=42, stratify=fullarray[:,-1])
train_set, val_set = train_test_split(bigtrain_set, test_size=0.2, random_state=42, stratify=bigtrain_set[:,-1])
# Out:
# (300, 20)
# (300,)
# (300, 21)

# %%
X_train = train_set[:,:-1]
y_train = train_set[:,-1]
X_test = test_set[:,:-1]
y_test = test_set[:,-1]
X_val = val_set[:,:-1]
y_val = val_set[:,-1]
print(f'Shapes are {[X_train.shape,y_train.shape,X_test.shape,y_test.shape,X_val.shape,y_val.shape]}')
# Out:
# Shapes are [(192, 20), (192,), (60, 20), (60,), (48, 20), (48,)]

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer

preproc_pl = Pipeline([ ('imputer', SimpleImputer(strategy="median")), ('scaler', StandardScaler())])

# %% [markdown]
# **KNN**

# %%
# Your code here
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import cross_validate
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.model_selection import GridSearchCV
import time

start = time.time()

knn_pl = Pipeline([ ('preproc',preproc_pl), ('knn',KNeighborsClassifier()) ])
knn_pl.fit(X_train,y_train)
y_knn_pred = knn_pl.predict(X_val)

# get original acc
b_acc = balanced_accuracy_score(y_val,y_knn_pred)
acc = accuracy_score(y_val,y_knn_pred)
print("orignal accuracy:", acc)
print("balanced accuracy:", b_acc)

print("--------------------------------------")

parameters = {'knn__n_neighbors':[1,3,5,7,9]}
gridcv = GridSearchCV(knn_pl, parameters, cv=5, scoring='neg_root_mean_squared_error')
gridcv.fit(X_train, y_train)
print(f'Best score is {-gridcv.best_score_} for best params of {gridcv.best_params_}')  



knn_pl_improve = Pipeline([ ('preproc',preproc_pl), 
                            ('knn',KNeighborsClassifier(n_neighbors=7)) ])
knn_pl_improve.fit(X_train,y_train)
y_knn_pred = knn_pl_improve.predict(X_val)
y_knn_test_pred = knn_pl_improve.predict(X_test)
y_knn_train_pred = knn_pl_improve.predict(X_train)

print("--------------------------------------")

# get improve acc
acc = balanced_accuracy_score(y_val,y_knn_pred)
print("improved accuracy:", acc)

# prec and recall
prec = precision_score(y_true = y_val, y_pred = y_knn_pred)
recl = recall_score(y_true = y_val, y_pred = y_knn_pred)
print(f'Precision & Recall are {prec} and {recl}')

# auc
fpr, tpr, thresholds = metrics.roc_curve(y_val, y_knn_pred, pos_label=1)
auc = metrics.auc(fpr, tpr)
print(f'AUC is {auc}')

# f1 score
f1 = f1_score(y_val, y_knn_pred)
print(f'F1 score is {f1}')

# f0.1 score
f01 = f01_score(y_val, y_knn_pred)
print(f'F0.1 score is {f01}')

# f10 score
f_score = f10_score(y_val, y_knn_pred)
print(f'F10 score is {f_score}') 

end = time.time()
 
print("--------------------------------------")

print("The time of execution of above program is :", end-start)
# Out:
# orignal accuracy: 0.9375
# balanced accuracy: 0.94
# --------------------------------------
# Best score is 0.21315139837811 for best params of {'knn__n_neighbors': 7}
# --------------------------------------
# improved accuracy: 0.96
# Precision & Recall are 1.0 and 0.92
# AUC is 0.96
# F1 score is 0.9583333333333334
# F0.1 score is 0.9991397849462366
# F10 score is 0.9207292905271502
# --------------------------------------
# The time of execution of above program is : 0.1792588233947754

# %% [markdown]
# **Decision Tree**

# %%
from sklearn.tree import DecisionTreeClassifier, plot_tree

start = time.time()

clf_pl = Pipeline([ ('preproc',preproc_pl), ('clf', DecisionTreeClassifier(random_state=3)) ])
clf_pl.fit(X_train,y_train)
y_clf_pred = clf_pl.predict(X_val)

# get original acc
b_acc = balanced_accuracy_score(y_val,y_clf_pred)
acc = accuracy_score(y_val,y_clf_pred)
print("orignal accuracy:", acc)
print("balanced accuracy:", b_acc)

print("--------------------------------------")

parameters = {'clf__random_state':[0,3,5,10,30,50]}
gridcv = GridSearchCV(clf_pl, parameters, cv=5, scoring='neg_root_mean_squared_error')
gridcv.fit(X_train, y_train)
print(f'Best score is {-gridcv.best_score_} for best params of {gridcv.best_params_}')  

print("--------------------------------------")

clf_pl_improve = Pipeline([ ('preproc',preproc_pl),
                            ('clf',DecisionTreeClassifier(random_state=20)) ])
clf_pl_improve.fit(X_train,y_train)
y_clf_pred = clf_pl_improve.predict(X_val)
y_clf_test_pred = clf_pl_improve.predict(X_test)
y_clf_train_pred = clf_pl_improve.predict(X_train)

# get improve acc
acc = balanced_accuracy_score(y_val,y_clf_pred)
print("improved accuracy:", acc)

# prec and recall
prec = precision_score(y_true = y_val, y_pred = y_clf_pred)
recl = recall_score(y_true = y_val, y_pred = y_clf_pred)
print(f'Precision & Recall are {prec} and {recl}')

# auc
fpr, tpr, thresholds = metrics.roc_curve(y_val, y_clf_pred, pos_label=1)
auc = metrics.auc(fpr, tpr)
print(f'AUC is {auc}')

# f1 score
f1 = f1_score(y_val, y_clf_pred)
print(f'F1 score is {f1}')

# f0.1 score
f01 = f01_score(y_val, y_clf_pred)
print(f'F0.1 score is {f01}')

# f10 score
f_score = f10_score(y_val, y_clf_pred)
print(f'F10 score is {f_score}') 

end = time.time()
 
print("--------------------------------------")

print("The time of execution of above program is :", end-start)
# Out:
# orignal accuracy: 0.875
# balanced accuracy: 0.88
# --------------------------------------
# Best score is 0.3056057446019609 for best params of {'clf__random_state': 5}
# --------------------------------------
# improved accuracy: 0.9182608695652175
# Precision & Recall are 0.9565217391304348 and 0.88
# AUC is 0.9182608695652174
# F1 score is 0.9166666666666666
# F0.1 score is 0.9556989247311829
# F10 score is 0.8806975822433611
# --------------------------------------
# The time of execution of above program is : 0.14613914489746094

# %% [markdown]
# **SVM**

# %%
from sklearn.svm import SVC

start = time.time()

svm_pl = Pipeline([('preproc',preproc_pl), ('svc',SVC(kernel='poly'))])
svm_pl.fit(X_train,y_train)
y_svm_pred = svm_pl.predict(X_val)

# get original acc
b_acc = balanced_accuracy_score(y_val,y_svm_pred)
acc = accuracy_score(y_val,y_svm_pred)
print("orignal accuracy:", acc)
print("balanced accuracy:", b_acc)

print("--------------------------------------")

parameters = {'svc__kernel':['linear','poly','rbf'], 'svc__random_state':[0,1,10,20,30,40,50]}
gridcv = GridSearchCV(svm_pl, parameters, cv=5, scoring='neg_root_mean_squared_error')
gridcv.fit(X_train, y_train)
print(f'Best score is {-gridcv.best_score_} for best params of {gridcv.best_params_}')  

print("--------------------------------------")

svm_pl_improve = Pipeline([('preproc',preproc_pl),
                            ('svc',SVC(kernel='rbf',random_state=0))])
svm_pl_improve.fit(X_train,y_train)
y_svm_pred = svm_pl_improve.predict(X_val)
y_svm_test_pred = svm_pl_improve.predict(X_test)
y_svm_train_pred = svm_pl_improve.predict(X_train)

# get improve acc
acc = balanced_accuracy_score(y_val,y_svm_pred)
print("improved accuracy:", acc)

# prec and recall
prec = precision_score(y_true = y_val, y_pred = y_svm_pred)
recl = recall_score(y_true = y_val, y_pred = y_svm_pred)
print(f'Precision & Recall are {prec} and {recl}')

# auc
fpr, tpr, thresholds = metrics.roc_curve(y_val, y_svm_pred, pos_label=1)
auc = metrics.auc(fpr, tpr)
print(f'AUC is {auc}')

# f1 score
f1 = f1_score(y_val, y_svm_pred)
print(f'F1 score is {f1}')

# f0.1 score
f01 = f01_score(y_val, y_svm_pred)
print(f'F0.1 score is {f01}')

# f10 score
f_score = f10_score(y_val, y_svm_pred)
print(f'F10 score is {f_score}') 

end = time.time()
 
print("--------------------------------------")

print("The time of execution of above program is :", end-start)
# Out:
# orignal accuracy: 0.9166666666666666
# balanced accuracy: 0.9130434782608696
# --------------------------------------
# Best score is 0.21315139837811 for best params of {'svc__kernel': 'rbf', 'svc__random_state': 0}
# --------------------------------------
# improved accuracy: 0.98
# Precision & Recall are 1.0 and 0.96
# AUC is 0.98
# F1 score is 0.9795918367346939
# F0.1 score is 0.9995876288659794
# F10 score is 0.9603803486529319
# --------------------------------------
# The time of execution of above program is : 0.46112632751464844

# %% [markdown]
# **SGD**

# %%
# sgd classifier
sgd_pl = Pipeline([ ('preproc',preproc_pl), ('sgd',SGDClassifier(loss='log')) ])
sgd_pl.fit(X_train,y_train)
y_sgd_pred = sgd_pl.predict(X_val)
y_sgd_prob = sgd_pl.predict_proba(X_val)

# get original acc
b_acc = balanced_accuracy_score(y_val,y_sgd_pred)
acc = accuracy_score(y_val,y_sgd_pred)
print("orignal accuracy:", acc)
print("balanced accuracy:", b_acc)



parameters = {'sgd__eta0':[1,0.1,0.01,0.001,0.0001,0.00001], 'sgd__loss':['log','hinge']}
gridcv = GridSearchCV(sgd_pl, parameters, cv=5, scoring='neg_root_mean_squared_error')
gridcv.fit(X_train, y_train)
print(f'Best score is {-gridcv.best_score_} for best params of {gridcv.best_params_}')
# Out:
# orignal accuracy: 0.9375
# balanced accuracy: 0.9347826086956521
# Best score is 0.22481966598895506 for best params of {'sgd__eta0': 0.01, 'sgd__loss': 'log'}

# %%
sgd_pl_improve = Pipeline([ ('preproc',preproc_pl),
                            ('sgd',SGDClassifier(eta0=0.01,loss='log',early_stopping=False)) ])
sgd_pl_improve.fit(X_train,y_train)
y_sgd_pred = sgd_pl_improve.predict(X_val)
y_sgd_test_pred = sgd_pl_improve.predict(X_test)
y_sgd_train_pred = sgd_pl_improve.predict(X_train)

print("---- first test ----")

# get improve acc
acc = balanced_accuracy_score(y_val,y_sgd_pred)
print("improved accuracy:", acc)

# prec and recall
prec = precision_score(y_true = y_val, y_pred = y_sgd_pred)
recl = recall_score(y_true = y_val, y_pred = y_sgd_pred)
print(f'Precision & Recall are {prec} and {recl}')

# auc
fpr, tpr, thresholds = metrics.roc_curve(y_val, y_sgd_pred, pos_label=1)
auc = metrics.auc(fpr, tpr)
print(f'AUC is {auc}')

# f1 score
f1 = f1_score(y_val, y_sgd_pred)
print(f'F1 score is {f1}')

# f0.1 score
f01 = f01_score(y_val, y_sgd_pred)
print(f'F0.1 score is {f01}')

# f10 score
f_score = f10_score(y_val, y_sgd_pred)
print(f'F10 score is {f_score}')
# Out:
# ---- first test ----
# improved accuracy: 0.94
# Precision & Recall are 1.0 and 0.88
# AUC is 0.94
# F1 score is 0.9361702127659575
# F0.1 score is 0.9986516853932584
# F10 score is 0.8810467882632831

# %%
sgd_pl_improve = Pipeline([ ('preproc',preproc_pl),
                            ('sgd',SGDClassifier(eta0=0.01,loss='log',early_stopping=False)) ])
sgd_pl_improve.fit(X_train,y_train)
y_sgd_pred = sgd_pl_improve.predict(X_val)
y_sgd_test_pred = sgd_pl_improve.predict(X_test)
y_sgd_train_pred = sgd_pl_improve.predict(X_train)

print("---- second test ----")

# get improve acc
acc = balanced_accuracy_score(y_val,y_sgd_pred)
print("improved accuracy:", acc)

# prec and recall
prec = precision_score(y_true = y_val, y_pred = y_sgd_pred)
recl = recall_score(y_true = y_val, y_pred = y_sgd_pred)
print(f'Precision & Recall are {prec} and {recl}')

# auc
fpr, tpr, thresholds = metrics.roc_curve(y_val, y_sgd_pred, pos_label=1)
auc = metrics.auc(fpr, tpr)
print(f'AUC is {auc}')

# f1 score
f1 = f1_score(y_val, y_sgd_pred)
print(f'F1 score is {f1}')

# f0.1 score
f01 = f01_score(y_val, y_sgd_pred)
print(f'F0.1 score is {f01}')

# f10 score
f_score = f10_score(y_val, y_sgd_pred)
print(f'F10 score is {f_score}')
# Out:
# ---- second test ----
# improved accuracy: 0.9199999999999999
# Precision & Recall are 1.0 and 0.84
# AUC is 0.9199999999999999
# F1 score is 0.9130434782608696
# F0.1 score is 0.9981176470588234
# F10 score is 0.8413328044426814

# %% [markdown]
# **Test**

# %%
# get acc --> KNN Classifier
acc1 = balanced_accuracy_score(y_test,y_knn_test_pred)
acc2 = balanced_accuracy_score(y_train,y_knn_train_pred)
print("KNN --> test accuracy:", acc1, " , and the train accuracy:", acc2)

# get acc --> Decision Tree Classifier
acc1 = balanced_accuracy_score(y_test,y_clf_test_pred)
acc2 = balanced_accuracy_score(y_train,y_clf_train_pred)
print("dt  --> test accuracy:", acc1, " , and the train accuracy:", acc2)

# get acc --> SVM Classifier
acc1 = balanced_accuracy_score(y_test,y_svm_test_pred)
acc2 = balanced_accuracy_score(y_train,y_svm_train_pred)
print("SVM --> test accuracy:", acc1, " , and the train accuracy:", acc2)

# get acc --> SGD Classifier
acc1 = balanced_accuracy_score(y_test,y_sgd_test_pred)
acc2 = balanced_accuracy_score(y_train,y_sgd_train_pred)
print("SGD --> test accuracy:", acc1, " , and the train accuracy:", acc2)
# Out:
# KNN --> test accuracy: 0.8654060066740823  , and the train accuracy: 0.9536474164133739
# dt  --> test accuracy: 0.8515016685205784  , and the train accuracy: 1.0
# SVM --> test accuracy: 0.882647385984427  , and the train accuracy: 0.9687364307425097
# SGD --> test accuracy: 0.8837597330367075  , and the train accuracy: 0.9476769431176726

# %% [markdown]
# About Accuracy:
#
# - KNN model: 0.87
# - DT  model: 0.85
# - SVM model: 0.88
# - SGD model: 0.88
#
#
# We can see that all accuracy become lower than original dataset which having worst cases.
#
# Due to SGD is not stable, I will also choose **SVM Classifier** to the clients.

# %% [markdown]
# **Confusion Matrix**

# %%
# draw confusion matrix of SVM
cmat = confusion_matrix(y_true=y_train, y_pred=y_svm_train_pred, normalize='all')
sns.heatmap(cmat,annot=True)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix --> train')
plt.show()

cmat = confusion_matrix(y_true=y_test, y_pred=y_svm_test_pred, normalize='all')
sns.heatmap(cmat,annot=True)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix --> test')
plt.show()

cmat = confusion_matrix(y_true=y_val, y_pred=y_svm_pred, normalize='all')
sns.heatmap(cmat,annot=True)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix --> val')
plt.show()

# %%
# get acc --> SVM Classifier
acc1 = balanced_accuracy_score(y_test,y_svm_test_pred)
acc2 = balanced_accuracy_score(y_train,y_svm_train_pred)
print("SVM --> test accuracy:", acc1, " , and the train accuracy:", acc2)
# Out:
# SVM --> test accuracy: 0.882647385984427  , and the train accuracy: 0.9687364307425097

# %% [markdown]
# ### 4.2 Performance difference [1 mark]
#
# Do you think the new classifier, that does not use the "worst" features, is:
#  - **as good as the previous classifier** (that uses all the features)
#  - **better than the previous classifier**
#  - **worse than the previous classifier**
#
# Give reasons for your answer.

# %% [markdown]
# **Your answer here**
#
# Worse than the previous classifier.
#
# Reason: Accuracy from 94.83% to 88.26%.
#
# - By using correlation in Q1.3, we can see that worst features have strong relation with the labels.
#
# - In rank features by using T-score, we can see that some worst features (worst radius, worst texture, worst perimeter and so on) are very related with negative and positive cases. So, it will influence the accuracy.
